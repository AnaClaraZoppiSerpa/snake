# %%
from pathlib import Path
import sys

sys.path.append(str(Path('').absolute().parent))


from stable_baselines3 import DQN
from stable_baselines3.dqn import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

from gym_snake.envs.SnakeEnv import SnakeEnv

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import random
random.seed(42)

# %%
def plot_metrics(metrics, filepath=None):
    formatted_dict = {'episodes': [],
                      'metrics': [],
                      'results': []}

    n = len(metrics['score'])
    for i in range(n):        
        score = metrics['score'][i]
        reward = metrics['reward'][i]

        formatted_dict['episodes'].append(i)
        formatted_dict['metrics'].append('score')
        formatted_dict['results'].append(score)

        formatted_dict['episodes'].append(i)
        formatted_dict['metrics'].append('reward')
        formatted_dict['results'].append(reward)

    df_metrics = pd.DataFrame(formatted_dict)
    sns.lineplot(data=df_metrics, x='episodes', y='results', hue='metrics')
    if filepath is None:
        plt.show()
    else:
        plt.savefig(filepath)
        
def evaluate(model):
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)
    obs = env.reset()

    for _ in range(10000):
        action, _states = model.predict(obs)
        obs, rewards, dones, info = env.step(action)
        env.render()

    return snake_env.record, np.mean(np.array(snake_env.results['score']))

# %%
results = {}
for _ in range(10):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    gamma = random.uniform(0.90, 1)
    
    model = DQN(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=gamma, learning_starts=10)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    
    results[gamma] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)

# %%
for gamma, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("Gamma", gamma)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# Gamma 0.9762510800075151
# Max Train Score 2 Max Test Score 1
# Mean Train Score 0.24621611461304815 Mean Test Score 0.0766698024459078
# ----------------------------------------------------------------------------------------------------
# Gamma 0.9152839268549635
# Max Train Score 2 Max Test Score 1
# Mean Train Score 0.24621611461304815 Mean Test Score 0.0766698024459078
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Testando: double_q

# %%
results = {}
for _ in range(10):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    gamma = random.uniform(0.95, 1)
    
    model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=gamma, double_q=False)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    
    results[gamma] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)
    
for gamma, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("Gamma", gamma)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-11487a7e094a> in <module>
#       7     gamma = random.uniform(0.95, 1)
#       8
# ----> 9     model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=gamma, double_q=False)
#      10     model.learn(total_timesteps=20000, log_interval=1000)
#      11
#
# TypeError: __init__() got an unexpected keyword argument 'double_q'

# %% [markdown]
# ### Testando: ent_coef

# %%
results = {}
for _ in range(10):
    # enable_render=True turns on the display
    snake_env = SnakeEnv(440, 440, enable_render=False)
    env = make_vec_env(lambda: snake_env, n_envs=1)

    entropy = random.uniform(0, 0.1)
    
    model = A2C(MlpPolicy, env, verbose=1, learning_rate=1e-3, seed=42, gamma=0.97, ent_coef=entropy)
    model.learn(total_timesteps=20000, log_interval=1000)

    # Print rewards and scores for each episode
    max_train_score = snake_env.record
    mean_train_score = np.mean(np.array(snake_env.results['score']))
    max_test_score, mean_test_score = evaluate(model)
    
    results[entropy] = (snake_env.results, max_train_score, max_test_score, mean_train_score, mean_test_score)
    
for entropy, result in results.items():
    metrics, max_train_score, max_test_score, mean_train_score, mean_test_score = result
    
    print("entropy", entropy)
    plot_metrics(metrics)    
    print("Max Train Score", max_train_score, "Max Test Score", max_test_score)
    print("Mean Train Score", mean_train_score, "Mean Test Score", mean_test_score)
    print("-"*100)
# Out:
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 91.8     |
# |    ep_rew_mean        | -43.5    |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 1000     |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.982   |
# |    explained_variance | 0.268    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0409   |
# |    value_loss         | 0.00126  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 87.9      |
# |    ep_rew_mean        | -13.6     |
# | time/                 |           |
# |    fps                | 219       |
# |    iterations         | 2000      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -0.0042   |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 1999      |
# |    policy_loss        | -0.000451 |
# |    value_loss         | 1.22      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 93.9      |
# |    ep_rew_mean        | 20        |
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 3000      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -0.00762  |
# |    explained_variance | 0.467     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 2999      |
# |    policy_loss        | -0.000429 |
# |    value_loss         | 1.14      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 115      |
# |    ep_rew_mean        | 38.7     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 4000     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.231   |
# |    explained_variance | 0.293    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.425   |
# |    value_loss         | 7.8      |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 76.4     |
# |    ep_rew_mean        | -34.6    |
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.848   |
# |    explained_variance | -44.5    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0482  |
# |    value_loss         | 0.008    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 62.5     |
# |    ep_rew_mean        | -10.6    |
# | time/                 |          |
# |    fps                | 278      |
# |    iterations         | 2000     |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.364   |
# |    explained_variance | 0.0832   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.625    |
# |    value_loss         | 2.69     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 90.3     |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.00116 |
# |    explained_variance | -3.4     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.000319 |
# |    value_loss         | 26.4     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 120       |
# |    ep_rew_mean        | 37.5      |
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 4000      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -8.27e-05 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -8.07e-06 |
# |    value_loss         | 2.04      |
# -------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 84.3     |
# |    ep_rew_mean        | -43.4    |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.947   |
# |    explained_variance | 0.177    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | 0.00968  |
# |    value_loss         | 0.00498  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82.8     |
# |    ep_rew_mean        | -23.2    |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.154   |
# |    explained_variance | -122     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.241    |
# |    value_loss         | 46.4     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95       |
# |    ep_rew_mean        | 12       |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 3000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.121   |
# |    explained_variance | 0.672    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.136    |
# |    value_loss         | 14.5     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 117       |
# |    ep_rew_mean        | 37.8      |
# | time/                 |           |
# |    fps                | 239       |
# |    iterations         | 4000      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.000175 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -2.21e-05 |
# |    value_loss         | 3.07      |
# -------------------------------------
# Using cpu device
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 90.6      |
# |    ep_rew_mean        | -43.9     |
# | time/                 |           |
# |    fps                | 235       |
# |    iterations         | 1000      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.04     |
# |    explained_variance | -0.28     |
# |    learning_rate      | 0.001     |
# |    n_updates          | 999       |
# |    policy_loss        | -0.000636 |
# |    value_loss         | 2.69e-06  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 88.6     |
# |    ep_rew_mean        | -26.8    |
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 2000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0251  |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.00196 |
# |    value_loss         | 0.36     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 81.3     |
# |    ep_rew_mean        | 4.1      |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 3000     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.186   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0344  |
# |    value_loss         | 0.679    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 105       |
# |    ep_rew_mean        | 29.8      |
# | time/                 |           |
# |    fps                | 244       |
# |    iterations         | 4000      |
# |    time_elapsed       | 81        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -0.000666 |
# |    explained_variance | nan       |
# |    learning_rate      | 0.001     |
# |    n_updates          | 3999      |
# |    policy_loss        | -8.85e-05 |
# |    value_loss         | 2.79      |
# -------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -35.1    |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | -0.422   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | -5.4     |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 2000     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0384  |
# |    explained_variance | 0.51     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0151  |
# |    value_loss         | 6.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 3000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0943  |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 4000     |
# |    time_elapsed       | 85       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.192    |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -35.1    |
# | time/                 |          |
# |    fps                | 277      |
# |    iterations         | 1000     |
# |    time_elapsed       | 18       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | -0.422   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | -5.4     |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 2000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0384  |
# |    explained_variance | 0.51     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0151  |
# |    value_loss         | 6.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 250      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0943  |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 4000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.192    |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -35.1    |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 1000     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | -0.422   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | -5.4     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 2000     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0384  |
# |    explained_variance | 0.51     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0151  |
# |    value_loss         | 6.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 3000     |
# |    time_elapsed       | 60       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0943  |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 4000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.192    |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -35.1    |
# | time/                 |          |
# |    fps                | 252      |
# |    iterations         | 1000     |
# |    time_elapsed       | 19       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | -0.422   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | -5.4     |
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 2000     |
# |    time_elapsed       | 38       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0384  |
# |    explained_variance | 0.51     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0151  |
# |    value_loss         | 6.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0943  |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 253      |
# |    iterations         | 4000     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.192    |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -35.1    |
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 1000     |
# |    time_elapsed       | 21       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | -0.422   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | -5.4     |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 2000     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0384  |
# |    explained_variance | 0.51     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0151  |
# |    value_loss         | 6.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 239      |
# |    iterations         | 3000     |
# |    time_elapsed       | 62       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0943  |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 249      |
# |    iterations         | 4000     |
# |    time_elapsed       | 80       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.192    |
# ------------------------------------
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 73.7     |
# |    ep_rew_mean        | -35.1    |
# | time/                 |          |
# |    fps                | 307      |
# |    iterations         | 1000     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.772   |
# |    explained_variance | -0.422   |
# |    learning_rate      | 0.001    |
# |    n_updates          | 999      |
# |    policy_loss        | -0.104   |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 82       |
# |    ep_rew_mean        | -5.4     |
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 2000     |
# |    time_elapsed       | 39       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -0.0384  |
# |    explained_variance | 0.51     |
# |    learning_rate      | 0.001    |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0151  |
# |    value_loss         | 6.96     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 95.9     |
# |    ep_rew_mean        | 20.8     |
# | time/                 |          |
# |    fps                | 251      |
# |    iterations         | 3000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.0943  |
# |    explained_variance | 0.317    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.0253   |
# |    value_loss         | 13.3     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 106      |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 257      |
# |    iterations         | 4000     |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.0968  |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.001    |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.103    |
# |    value_loss         | 0.192    |
# ------------------------------------
# entropy 0.017409100974870008
# Max Train Score 24 Max Test Score 30
# Mean Train Score 3.0192363943405867 Mean Test Score 5.461390533238072
# ----------------------------------------------------------------------------------------------------
# entropy 0.008359707377781633
# Max Train Score 25 Max Test Score 30
# Mean Train Score 2.89886086677891 Mean Test Score 7.131032686361102
# ----------------------------------------------------------------------------------------------------
# entropy 0.0402850773301821
# Max Train Score 23 Max Test Score 31
# Mean Train Score 2.835303307190924 Mean Test Score 6.407545348787234
# ----------------------------------------------------------------------------------------------------
# entropy 0.03977158681886638
# Max Train Score 23 Max Test Score 31
# Mean Train Score 2.5979289747169805 Mean Test Score 6.097508975742374
# ----------------------------------------------------------------------------------------------------
# entropy 0.01142066513589688
# Max Train Score 22 Max Test Score 26
# Mean Train Score 2.9724339132991875 Mean Test Score 4.751743223589518
# ----------------------------------------------------------------------------------------------------
